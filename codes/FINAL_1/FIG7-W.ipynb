# %%
import os
from os.path import expanduser
import socket
import sys
import glob

# BELOW IS SYSTEM/PATH CONFIGURATION #
my_home = expanduser("~")
running_system = socket.gethostname()
# Configure machine's names here #
systemHLRN = 'blogin1'
systemLOCAL = 'Laurents-MacBook-Pro.local'
my_home = expanduser("~")
# Define local pass #
wd_path = '/home/hbkoziel/pyfesom/'
save_path = wd_path+'/figures/Arc12/FINAL/'

#sys.path.append("codes/modules") # add custom Vibe 's modules
sys.path.append('../..') # add standard 's modules
sys.path.append('../modules')
#########################################

# %%
import pyfesom as pf
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
import numpy as np
from netCDF4 import Dataset
import os
import time

import xarray as xr
import pandas as pd
sys.path.append('/home/hbkoziel/pyfesom/pyfesom/cmocean/')
import cmocean as cmap
# Out:
# No joblib
# no cmocean

# %%
# Loading mesh for run

mesh_id    = 'meshArc4.5'
meshpath   = '/home/hbkoziel/pyfesom/data/mesh/'+mesh_id+'/'            # Defining path where mesh is stored
mesh = pf.load_mesh(meshpath, usepickle=True, get3d=True)                                    # Loading mesh, stores it in mesh.****  
#mesh = pf.fesom_mesh(meshpath, get3d=True)
#mesh.zlevs = -mesh.zlevs                                            # Depth is made negative

first_year = 1985
last_year  = 2015
years      = np.arange(first_year,last_year+1,1)
runid	= 'Arc12'

data_path  = '/scratch/usr/hbkoziel/'+runid+'/netcdf/'
# Out:
# /home/hbkoziel/pyfesom/data/mesh/meshArc4.5/pickle_mesh
# 2
# The usepickle == True)
# The pickle file for python 2 exists.
# The mesh will be loaded from /home/hbkoziel/pyfesom/data/mesh/meshArc4.5/pickle_mesh

# %%
tracername = 'WAPE'
time = pd.date_range('1985-01-01', freq="YS", periods= len(np.arange(1985,2016,1)))
data = xr.open_mfdataset(data_path+tracername+'*v2.nc', concat_dim='time')
data['time'] = time

APE_sel = data.APE.sel(time=slice(str(first_year)+'-01-01', str(last_year)+'-12-31'))
APE_sel = APE_sel.compute()
APE_sel = APE_sel.fillna(0)
# CUR_march = CUR_sel[data['time.month']==3]
# CUR_march = CUR_march.compute()

APE_sept_mean = APE_sel.mean(dim='time')
APE_sept_mean = APE_sept_mean.compute()

pf = np.polyfit(years, APE_sel, 1)
APE_trend = pf[0]

ind_fram = (np.array(np.abs(mesh.x2)<20) & np.array(mesh.y2<80))
APE_trend[ind_fram]=np.nan
APE_sept_mean[ind_fram]=np.nan

# %%
tracername = 'mixlay'
time = pd.date_range('1985-01-01', freq="MS", periods= 12*len(np.arange(1985,2016,1)))
data = xr.open_mfdataset(data_path+tracername+'*.nc', concat_dim='time')
data['time'] = time

MLD_sel = data.mixlay.sel(time=slice(str(first_year)+'-01-01', str(last_year)+'-12-31'))
MLD_sel = MLD_sel.compute()

# CUR_march = CUR_sel[data['time.month']==3]
# CUR_march = CUR_march.compute()

MLD_sept = MLD_sel[data['time.month']==3]
MLD_sept = MLD_sept.compute()
MLD_sept_mean = MLD_sept.mean(dim='time')
MLD_sept_mean = MLD_sept_mean.compute()

pf = np.polyfit(years, MLD_sept, 1)
MLD_trend = pf[0]

# %%
import pyfesom as pf
fig = plt.figure(figsize=(15, 15), facecolor='w', edgecolor='k')

MLD_sept_mean[MLD_sept_mean == 0] = np.nan
data, elem_no_nan = pf.get_data(MLD_sept_mean,mesh,0)
ax1      = fig.add_subplot(221)
contours = np.arange(0, 300, 1)
m = Basemap(projection='nplaea',boundinglat=70,lon_0=0,resolution='l')
x, y = m(mesh.x2, mesh.y2)
plabels=[False,False,False,False]
mlabels=[False,False,False,False]    
m.drawparallels(np.arange(-80.,81.,20.), labels=plabels)
m.drawmeridians(np.arange(-180.,181.,20.),labels=mlabels) #[0,1,0,0]
m.drawmapboundary(fill_color='0.7')
m.fillcontinents(color='.5',lake_color='.7')
im=plt.tricontourf(x, y, elem_no_nan, (data) , levels=contours, cmap=cmap.cm.deep, extend='max')
label = 'MLD (m)'
cbar=m.colorbar(im,"bottom", size="5%", pad="2%")
cbar.set_label(label, fontsize=14)
cbar.ax.tick_params(labelsize=12)
plt.title('Winter [Mar.] mean', fontsize=16)

MLD_trend[MLD_trend == 0] = np.nan
data2, elem_no_nan = pf.get_data(MLD_trend,mesh,0) 
ax2      = fig.add_subplot(222)
contours = np.arange(-8, 8, .1)
m = Basemap(projection='nplaea',boundinglat=70,lon_0=0,resolution='l')
x, y = m(mesh.x2, mesh.y2)
#map.drawcoastlines()
plabels=[False,False,False,False]
mlabels=[False,False,False,False]    
m.drawparallels(np.arange(-80.,81.,20.), labels=plabels)
m.drawmeridians(np.arange(-180.,181.,20.),labels=mlabels) #[0,1,0,0]
m.drawmapboundary(fill_color='0.7')
m.fillcontinents(color='.5',lake_color='.7')
eps=(contours.max()-contours.min())/100.
data2[data2<=contours.min()]=contours.min()+eps
data2[data2>=contours.max()]=contours.max()-eps
im=plt.tricontourf(x, y, elem_no_nan, data2, levels=contours, cmap=cmap.cm.balance, extend='both')
label = 'MLD (m)'
cbar=m.colorbar(im,"bottom", size="5%", pad="2%")
cbar.set_label(label, fontsize=14)
cbar.ax.tick_params(labelsize=12)
plt.title('Winter [Mar.] trend', fontsize=16)

APE_sept_mean[APE_sept_mean == 0] = np.nan
data, elem_no_nan = pf.get_data(APE_sept_mean/10**5,mesh,0)
ax3      = fig.add_subplot(223)
contours = np.arange(0, 10, .01)
m = Basemap(projection='nplaea',boundinglat=70,lon_0=0,resolution='l')
x, y = m(mesh.x2, mesh.y2)
plabels=[False,False,False,False]
mlabels=[False,False,False,False]    
m.drawparallels(np.arange(-80.,81.,20.), labels=plabels)
m.drawmeridians(np.arange(-180.,181.,20.),labels=mlabels) #[0,1,0,0]
m.drawmapboundary(fill_color='0.7')
m.fillcontinents(color='.5',lake_color='.7')
eps=(contours.max()-contours.min())/100.
data[data<=contours.min()]=contours.min()+eps
data[data>=contours.max()]=contours.max()-eps
im=plt.tricontourf(x, y, elem_no_nan, data , levels=contours, cmap=cmap.cm.thermal, extend='max')
label = 'APE (x 10$^{5}$ J m$^{-2}$)'
cbar=m.colorbar(im,"bottom", size="5%", pad="2%")
cbar.set_label(label, fontsize=14)
cbar.ax.tick_params(labelsize=12)

APE_trend[APE_trend == 0] = np.nan
data2, elem_no_nan = pf.get_data(APE_trend/10**5,mesh,0) 
ax4      = fig.add_subplot(224)
contours = np.arange(-.6, .6, .01)
m = Basemap(projection='nplaea',boundinglat=70,lon_0=0,resolution='l')
x, y = m(mesh.x2, mesh.y2)
#map.drawcoastlines()
plabels=[False,False,False,False]
mlabels=[False,False,False,False]    
m.drawparallels(np.arange(-80.,81.,20.), labels=plabels)
m.drawmeridians(np.arange(-180.,181.,20.),labels=mlabels) #[0,1,0,0]
m.drawmapboundary(fill_color='0.7')
m.fillcontinents(color='.5',lake_color='.7')
eps=(contours.max()-contours.min())/100.
data2[data2<=contours.min()]=contours.min()+eps
data2[data2>=contours.max()]=contours.max()-eps
im=plt.tricontourf(x, y, elem_no_nan, data2, levels=contours, cmap=cmap.cm.balance, extend='both')
label = 'APE (x 10$^{5}$ J m$^{-2}$)'
cbar=m.colorbar(im,"bottom", size="5%", pad="2%")
cbar.set_label(label, fontsize=14)
cbar.ax.tick_params(labelsize=12)

fig.subplots_adjust(wspace=0.02,hspace=0.12)

plt.savefig(save_path+'FIG7-W.png', dpi = 300, bbox_inches='tight')
# Out:
# For depth 0 model level -0.0 will be used
# For depth 0 model level -0.0 will be used
# For depth 0 model level -0.0 will be used
# /sw/tools/anaconda2/2019.10/skl/lib/python2.7/site-packages/ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in less_equal
# /sw/tools/anaconda2/2019.10/skl/lib/python2.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in greater_equal
# For depth 0 model level -0.0 will be used
# /sw/tools/anaconda2/2019.10/skl/lib/python2.7/site-packages/ipykernel_launcher.py:81: RuntimeWarning: invalid value encountered in less_equal
# /sw/tools/anaconda2/2019.10/skl/lib/python2.7/site-packages/ipykernel_launcher.py:82: RuntimeWarning: invalid value encountered in greater_equal
