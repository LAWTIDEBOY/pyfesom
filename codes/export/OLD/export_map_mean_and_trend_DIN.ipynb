# %%
import os
from os.path import expanduser
import socket
import sys


# BELOW IS SYSTEM/PATH CONFIGURATION #
my_home = expanduser("~")
running_system = socket.gethostname()
# Configure machine's names here #
systemHLRN = 'blogin1'
systemLOCAL = 'Laurents-MacBook-Pro.local'
my_home = expanduser("~")
# Define local pass #
if running_system == systemLOCAL:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"Documents","projects", "awi-models")
elif running_system[0] == "b" or running_system == systemHLRN:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"awi-models")
else:
    print 'please configure your local machine : type socket.gethostname()'
print "working directory set to", wd_path
os.chdir(wd_path)
sys.path.append("codes/modules")
#########################################
# Out:
# computer =  bfn1003
# working directory set to /home/hbkoziel/awi-models

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from pylab import *
from load_mesh_data_new import *
import numpy as np
from PiecewiseNorm import PiecewiseNorm
from netCDF4 import Dataset
import colormaps as cmaps
from matplotlib.colors import ListedColormap

# %%
import os
from os.path import expanduser
import socket
import sys


# BELOW IS SYSTEM/PATH CONFIGURATION #
my_home = expanduser("~")
running_system = socket.gethostname()
# Configure machine's names here #
systemHLRN = 'blogin1'
systemLOCAL = 'Laurents-MacBook-Pro.local'
my_home = expanduser("~")
# Define local pass #
if running_system == systemLOCAL:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"Documents","projects", "awi-models")
elif running_system[0] == "b" or running_system == systemHLRN:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"awi-models")
else:
    print 'please configure your local machine : type socket.gethostname()'
print "working directory set to", wd_path
os.chdir(wd_path)
sys.path.append("codes/modules")
#########################################
# Out:
# computer =  bfn1003
# working directory set to /home/hbkoziel/awi-models

# %%
# PLOT CONFIGURATION #

# CSV export
export_csv = True
# figure export definition
dpicnt=150
# choose simulation
runid='Arc12'
# choose date
first_year = 1990
last_year  = 2015
years      = np.arange(first_year,last_year+1,1)
months =np.linspace(0,11,12).astype(int)
# choose depth
get3d = False
# load the given biological tracer #
var_id = 'tr01' #DIN

########################

# AUTOMATIC DEFINITION OF PATHS
resultpath = '/scratch/usr/hbkvsk12/hlrn3_work2/results/'+runid+'/Oldfiles/'
savepath    = wd_path+'/figures/'+runid+'/'
meshpath    = wd_path+'/data/mesh/meshArc4.5/'
outputpath = '/scratch/usr/hbkoziel/Arc12/'

# Create figure directory if it does not exist
if os.path.exists(savepath) == False:
    try:
        os.mkdir(savepath)
        print ("Creation of the directory %s successfull" % savepath)
    except OSError:
        print ("Creation of the directory %s failed" % savepath)
else:
    print ("directory %s already existing" % savepath)
# Out:
# directory /home/hbkoziel/awi-models/figures/Arc12/ already existing

# %%
mesh = fesom_mesh(meshpath, get3d = get3d)
# Out:
# Load 2d part of the grid in 3 second(s)

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))

for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][4,0:mesh.n2d]
     else:
         din    = f.variables[var_id][45:59,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_APR_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_APR_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  5.306857394166154
# Max and min:  4288.9846426156855 0.007531988792694532
# exporting done

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][5,0:mesh.n2d]
     else:
         din    = f.variables[var_id][60:74,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_MAY_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_MAY_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  4.146967385118281
# Max and min:  4057.0535747821514 0.007545441156253219
# exporting done

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][6,0:mesh.n2d]
     else:
         din    = f.variables[var_id][75:89,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_JUN_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_JUN_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  3.1172974307674814
# Max and min:  2906.44340632512 0.006824155051547747
# exporting done

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][7,0:mesh.n2d]
     else:
         din    = f.variables[var_id][90:105,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_JUL_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_JUL_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  2.5420767739044594
# Max and min:  2433.6076941856973 0.006853577322684801
# exporting done

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][8,0:mesh.n2d]
     else:
         din    = f.variables[var_id][106:120,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_AUG_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_AUG_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  2.293724411994591
# Max and min:  2355.5404240534854 0.007943983333042035
# exporting done

# %%
DIN2D = np.zeros((len(years),len(mesh.x2)))
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.oce.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         din    = f.variables[var_id][9,0:mesh.n2d]
     else:
         din    = f.variables[var_id][121:135,0:mesh.n2d].mean(axis=0)
     DIN2D[ind,:]=din[:]

data2 = DIN2D.mean(axis=0)
print 'Number of nans in tracer: ',var_id,np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',var_id,np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'DIN_SEP_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'DIN_SEP_'+str(first_year)+'_'+str(last_year)+'_trend.csv', DIN2D, delimiter=";")
    print 'exporting done'
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  tr01 0
# Number of inf in tracer:  tr01 0
# Mean of surface:  2.6974622965070774
# Max and min:  2262.1890258789062 0.009768706352378313
# exporting done
