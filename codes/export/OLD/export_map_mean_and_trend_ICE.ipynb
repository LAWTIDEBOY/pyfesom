# %%
import os
from os.path import expanduser
import socket
import sys


# BELOW IS SYSTEM/PATH CONFIGURATION #
my_home = expanduser("~")
running_system = socket.gethostname()
# Configure machine's names here #
systemHLRN = 'blogin1'
systemLOCAL = 'Laurents-MacBook-Pro.local'
my_home = expanduser("~")
# Define local pass #
if running_system == systemLOCAL:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"Documents","projects", "awi-models")
elif running_system[0] == "b" or running_system == systemHLRN:
    print "computer = ", running_system
    wd_path = os.path.join(my_home,"awi-models")
else:
    print 'please configure your local machine : type socket.gethostname()'
print "working directory set to", wd_path
os.chdir(wd_path)
sys.path.append("codes/modules")
#########################################
# Out:
# computer =  bcn1670
# working directory set to /home/hbkoziel/awi-models

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from pylab import *
from load_mesh_data_new import *
import numpy as np
from PiecewiseNorm import PiecewiseNorm
from netCDF4 import Dataset
import colormaps as cmaps
from matplotlib.colors import ListedColormap

# %%
# PLOT CONFIGURATION #

# CSV export
export_csv = True
# figure export definition
dpicnt=150
# choose simulation
runid='Arc12'
# choose date
first_year = 1990
last_year  = 2015
years      = np.arange(first_year,last_year+1,1)
months =np.linspace(0,11,12).astype(int)
# choose depth
get3d = False
# load the given biological tracer #
var_id= 'area'
########################

# AUTOMATIC DEFINITION OF PATHS
resultpath = '/scratch/usr/hbkvsk12/hlrn3_work2/results/'+runid+'/Oldfiles/'
savepath    = wd_path+'/figures/'+runid+'/'
meshpath    = wd_path+'/data/mesh/meshArc4.5/'
outputpath = '/scratch/usr/hbkoziel/Arc12/'

# Create figure directory if it does not exist
if os.path.exists(savepath) == False:
    try:
        os.mkdir(savepath)
        print ("Creation of the directory %s successfull" % savepath)
    except OSError:
        print ("Creation of the directory %s failed" % savepath)
else:
    print ("directory %s already existing" % savepath)
# Out:
# directory /home/hbkoziel/awi-models/figures/Arc12/ already existing

# %%
mesh = fesom_mesh(meshpath, get3d = get3d)
# Out:
# Load 2d part of the grid in 2 second(s)

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][4,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][45:59,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_APR_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_APR_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.6174548288894408
# Max and min:  0.9999827375778785 0.0

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][5,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][60:74,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_MAY_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_MAY_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.5730388765637175
# Max and min:  0.9998901738570287 0.0

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][6,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][75:89,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_JUN_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_JUN_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.4896753758274369
# Max and min:  0.99980045740421 0.0

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][7,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][90:105,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_JUL_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_JUL_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.3822040444275261
# Max and min:  0.9997617556498601 0.0

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][8,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][106:120,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_AUG_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_AUG_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.31701122530113307
# Max and min:  0.9997966610468351 0.0

# %%
# initlialyze
ICE = np.zeros((len(years),len(mesh.x2)))

# loop over years
for ind in range(0,len(years)):
     print years[ind]
     ncfile = resultpath+runid+'.'+str(years[ind])+'.ice.mean.nc'
     f      = Dataset(ncfile, 'r')
     if years[ind]<2000:
         ice    = f.variables[var_id][9,0:mesh.n2d]
     else:
         ice    = f.variables[var_id][121:135,0:mesh.n2d].mean(axis=0)
     ICE[ind,:] = ice

data2 = ICE.mean(axis=0)
print 'Number of nans in tracer: ',np.count_nonzero(np.isnan(data2))
print 'Number of inf in tracer: ',np.count_nonzero(np.isinf(data2))
print 'Mean of surface: ',np.mean(data2[0:len(mesh.x2)])
print 'Max and min: ',np.max(data2),np.min(data2)

if export_csv == True:
    np.savetxt(outputpath+'ICE_SEP_'+str(first_year)+'_'+str(last_year)+'_mean.csv', data2, delimiter=";")
    np.savetxt(outputpath+'ICE_SEP_'+str(first_year)+'_'+str(last_year)+'_trend.csv', ICE, delimiter=";")
# Out:
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# Number of nans in tracer:  0
# Number of inf in tracer:  0
# Mean of surface:  0.346989018699229
# Max and min:  0.9997854209863223 0.0
