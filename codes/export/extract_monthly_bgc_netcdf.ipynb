# %%
import sys 
#sys.path.append("codes/modules") # add custom Vibe 's modules
sys.path.append("../..") # add standard 's modules
sys.path.append('../modules')

import pyfesom as pf
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
import numpy as np
from netCDF4 import Dataset
import os
import time

# %%
# ==============================================================================
# Running this file loads tracers from old FESOM-REcoM2 output file (oce.mean.nc)
# and saves each tracer in an individual file
# 
#  Input:
#  - mesh_id: Name of mesh, will be added to the netcdf name
#  - meshpath: Speciefies where the target mesh is stored
#  - save_netcdf: If true, netcdf will be created
#  - delete_old_netcdf: If a netcdf file with the same name exists, a new cannot 
#    be made. If set to true, an old netcdf with the same name will be deleted
#
#  Output:
#  - netcdf file for each tracer in the old file
#  
#  During running, keep an eye on the output in the terminal, to see if it 
#  makes sense. 
#
# ==============================================================================

# %%
# Loading mesh for run

mesh_id    = 'meshArc4.5'
meshpath   = '/home/hbkoziel/pyfesom/data/mesh/'+mesh_id+'/'            # Defining path where mesh is stored
mesh = pf.load_mesh(meshpath, usepickle=True, get3d=True)                                    # Loading mesh, stores it in mesh.****  
#mesh = pf.fesom_mesh(meshpath, get3d=True)
#mesh.zlevs = -mesh.zlevs                                            # Depth is made negative


first_year = 1980
last_year  = 2015
years      = np.arange(first_year,last_year+1,1)
runid	= 'Arc12'
# Out:
# /home/hbkoziel/pyfesom/data/mesh/meshArc4.5/pickle_mesh
# 2
# The usepickle == True)
# The pickle file for python 2 exists.
# The mesh will be loaded from /home/hbkoziel/pyfesom/data/mesh/meshArc4.5/pickle_mesh

# %%
# ==============================================================================
# Settings for netcdf file

save_netcdf       = True                                            # Saves the interpolated field in netcdf file
delete_old_netcdf = True                                            # If a netcdf file with the same name exists it will be deleted
input_directory  = '/scratch/usr/hbkvsk12/hlrn3_work2/results/' # Where the netcdf is saved
output_directory  = '/scratch/usr/hbkoziel/'+runid+'/netcdf/'
plot_netcdf       = True                                           # Reads DIN from the created netcdf file, else it plots the interpolated field (should be the same)

# %%
for ind_tracer in range(1,22):
    if ind_tracer <= 9:
        tracername = 'tr0'+str(ind_tracer)
    else:
        tracername = 'tr'+str(ind_tracer)
    for ind in range(0,len(years)):
        netcdf_name       = tracername+'.'+str(years[ind])+'.monthly.nc'

        # ==============================================================================
        # Loading data

        ncfile	= input_directory+runid+'/Oldfiles/'+runid+'.'+str(years[ind])+'.oce.mean.nc'
        f	= Dataset(ncfile,'r')
        tracer	= f.variables[tracername][:]
        if years[ind] >= 2000:
            t1 = np.mean(tracer[0:15,:],axis=0)
            t2 = np.mean(tracer[15:29,:],axis=0)
            t3 = np.mean(tracer[29:45,:],axis=0)
            t4 = np.mean(tracer[45:60,:],axis=0)
            t5 = np.mean(tracer[60:75,:],axis=0)
            t6 = np.mean(tracer[75:90,:],axis=0)
            t7 = np.mean(tracer[90:106,:],axis=0)
            t8 = np.mean(tracer[106:121,:],axis=0)
            t9 = np.mean(tracer[121:136,:],axis=0)
            t10 = np.mean(tracer[136:152,:],axis=0)
            t11 = np.mean(tracer[152:167,:],axis=0)
            t12 = np.mean(tracer[166:,:],axis=0)
            tracer = [t1,t2,t3,t4,t5,t6,t7,t8,t9,t10,t11,t12]
        else:
            t1 = tracer[0,:]
            t2 = tracer[1,:]
            t3 = tracer[2,:]
            t4 = tracer[3,:]
            t5 = tracer[4,:]
            t6 = tracer[5,:]
            t7 = tracer[6,:]
            t8 = tracer[7,:]
            t9 = tracer[8,:]
            t10 = tracer[9,:]
            t11 = tracer[10,:]
            t12 = tracer[11,:]
            tracer = [t1,t2,t3,t4,t5,t6,t7,t8,t9,t10,t11,t12]

        tracershape = np.shape(tracer)

        # ==============================================================================
        # Testing if a netcdf file with the same name exists, if yes, it must be removed
        # to save a new one.

        if os.path.isfile(output_directory+netcdf_name) and delete_old_netcdf:
          os.remove(output_directory+netcdf_name)
          print "The netcdf file "+netcdf_name+" has been deleted to make room for your file of the same name."
        elif os.path.isfile(netcdf_name):
          statement = "The netcdf file "+netcdf_name+" already exists! It must be removed for a new one to be created. This can be done by changing your settings."
          sys.exit(statement)

        if not os.path.isdir(output_directory):
          os.makedirs(output_directory)
          print 'Directory '+output_directory+' has been created'

        # ==============================================================================
        # Creating netcdf file
        if save_netcdf:  
          import time
          w_nc_fid = Dataset(output_directory+netcdf_name, 'w', format='NETCDF4_CLASSIC')      # Create and open new netcdf file to write to
          w_nc_fid.description = f.variables[tracername].description
          w_nc_fid.history     = 'Created ' + time.ctime(time.time())

          nod3d    = w_nc_fid.createDimension('nod3d', mesh.n3d)               # Create dimension: number of 3d nodes
          time	   = w_nc_fid.createDimension('time', tracershape[0]) 

          w_nc_var = w_nc_fid.createVariable(tracername, 'f8',('time','nod3d'))           # 'DIN' is name of saved variable
                                                                               # 'f8' sets presicion to 64-bit floating point
          w_nc_var.setncatts({'long_name': f.variables[tracername].description,\
                              'units': 'NA'})
          w_nc_fid.variables[tracername][:] = tracer   
          w_nc_fid.close()                                                     # close the new file                

          cwd = os.getcwd()
          print "New netcdf file (",netcdf_name,") has been created."
          print "Location: "+output_directory
        else:
          print 'You have specified not to save your field in netcdf file'
# Out:
# New netcdf file ( tr01.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr01.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr02.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr03.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr04.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr05.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr06.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr07.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr08.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr09.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr10.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr11.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr12.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr13.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# ...
# New netcdf file ( tr17.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr17.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr18.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr19.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr20.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1980.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1981.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1982.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1983.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1984.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1985.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1986.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1987.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1988.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1989.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1990.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1991.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1992.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1993.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1994.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1995.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1996.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1997.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1998.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.1999.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2000.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2001.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2002.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2003.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2004.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2005.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2006.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2007.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2008.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2009.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2010.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2011.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2012.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2013.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2014.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
# New netcdf file ( tr21.2015.monthly.nc ) has been created.
# Location: /scratch/usr/hbkoziel/Arc12/netcdf/
